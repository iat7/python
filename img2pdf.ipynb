# %%
import img2pdf

# %%
path_to_input = input()
# Out:
# C:\Users\ITregubov\Desktop\SIZE_PHOTO_BASE\Док_ 31_07_17 17_01_55\

# %%
print (path_to_input)
# Out:
# C:\Users\ITregubov\Desktop\SIZE_PHOTO_BASE\Док_ 31_07_17 17_01_55\

# %%
f = open(path_to_input+"name.pdf","wb")
print (path_to_input+"name.pdf")
f.write(img2pdf.convert(path_to_input+'017_jpeg2000_0.jp2'))
f.close()
# Out:
# C:\Users\ITregubov\Desktop\SIZE_PHOTO_BASE\Док_ 31_07_17 17_01_55\name.pdf

# %%
import os

# %%
ALL_FILES_INPUT = os.listdir(path_to_input)

# %%
try:
    os.makedirs(path_to_input+'\Result')
except OSError:
    pass

# %%
NUM_OF_IMGS = len(ALL_FILES_INPUT)
i = 0
while i < NUM_OF_IMGS:
    print(ALL_FILES_INPUT[i])
    i += 1
else:
    print('Цикл окончен, i =', i)
# Out:
# 001.jpg
# 001_jpeg2000_0.jp2
# 001_jpeg2000_1.jp2
# 001_jpeg2000_10.jp2
# 001_jpeg2000_11.jp2
# 001_jpeg2000_12.jp2
# 001_jpeg2000_13.jp2
# 001_jpeg2000_14.jp2
# 001_jpeg2000_15.jp2
# 001_jpeg2000_16.jp2
# 001_jpeg2000_17.jp2
# 001_jpeg2000_18.jp2
# 001_jpeg2000_19.jp2
# 001_jpeg2000_2.jp2
# 001_jpeg2000_20.jp2
# 001_jpeg2000_3.jp2
# 001_jpeg2000_4.jp2
# 001_jpeg2000_5.jp2
# 001_jpeg2000_6.jp2
# 001_jpeg2000_7.jp2
# 001_jpeg2000_8.jp2
# 001_jpeg2000_9.jp2
# 002.jpg
# 002_jpeg2000_0.jp2
# 002_jpeg2000_1.jp2
# 002_jpeg2000_10.jp2
# 002_jpeg2000_11.jp2
# 002_jpeg2000_12.jp2
# 002_jpeg2000_13.jp2
# 002_jpeg2000_14.jp2
# 002_jpeg2000_15.jp2
# 002_jpeg2000_16.jp2
# 002_jpeg2000_17.jp2
# 002_jpeg2000_18.jp2
# 002_jpeg2000_19.jp2
# 002_jpeg2000_2.jp2
# 002_jpeg2000_20.jp2
# 002_jpeg2000_3.jp2
# 002_jpeg2000_4.jp2
# 002_jpeg2000_5.jp2
# 002_jpeg2000_6.jp2
# 002_jpeg2000_7.jp2
# 002_jpeg2000_8.jp2
# 002_jpeg2000_9.jp2
# 003.jpg
# 003_jpeg2000_0.jp2
# 003_jpeg2000_1.jp2
# 003_jpeg2000_10.jp2
# ...

# %%
i = 0
while i < NUM_OF_IMGS:
    f = open(path_to_input + str(i) + ".pdf","wb")
    print(path_to_input + str(i) + ".pdf")
    f.write(img2pdf.convert(path_to_input+ALL_FILES_INPUT[i]))
    f.close()
    i += 1
else:
    print('Цикл окончен, i =', i)
# Out:
# C:\Users\ITregubov\Desktop\SIZE_PHOTO_BASE\Док_ 31_07_17 17_01_55\0.pdf
# C:\Users\ITregubov\Desktop\SIZE_PHOTO_BASE\Док_ 31_07_17 17_01_55\1.pdf
# C:\Users\ITregubov\Desktop\SIZE_PHOTO_BASE\Док_ 31_07_17 17_01_55\2.pdf
# C:\Users\ITregubov\Desktop\SIZE_PHOTO_BASE\Док_ 31_07_17 17_01_55\3.pdf
# C:\Users\ITregubov\Desktop\SIZE_PHOTO_BASE\Док_ 31_07_17 17_01_55\4.pdf
# C:\Users\ITregubov\Desktop\SIZE_PHOTO_BASE\Док_ 31_07_17 17_01_55\5.pdf
# C:\Users\ITregubov\Desktop\SIZE_PHOTO_BASE\Док_ 31_07_17 17_01_55\6.pdf
# C:\Users\ITregubov\Desktop\SIZE_PHOTO_BASE\Док_ 31_07_17 17_01_55\7.pdf
# C:\Users\ITregubov\Desktop\SIZE_PHOTO_BASE\Док_ 31_07_17 17_01_55\8.pdf
# C:\Users\ITregubov\Desktop\SIZE_PHOTO_BASE\Док_ 31_07_17 17_01_55\9.pdf
# C:\Users\ITregubov\Desktop\SIZE_PHOTO_BASE\Док_ 31_07_17 17_01_55\10.pdf
# C:\Users\ITregubov\Desktop\SIZE_PHOTO_BASE\Док_ 31_07_17 17_01_55\11.pdf
# C:\Users\ITregubov\Desktop\SIZE_PHOTO_BASE\Док_ 31_07_17 17_01_55\12.pdf
# ...
